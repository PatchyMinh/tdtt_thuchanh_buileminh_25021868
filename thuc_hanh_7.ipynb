# %%
# W7A1

lstIn = list(map(int, input().split()))
intIn = int(input())
left = 0
right = len(lstIn)
def binary_search(arr, left, right, target):
    while left != right:
        mid = (left + right)//2
        if lstIn[mid] == target:
            return mid
        else:
            if lstIn[mid] < target:
                left = mid + 1
            else:
                right = mid - 1
    return -1

binary_search(lstIn, left, right, intIn)
# Out:
# -1

# %%
# W7A2

import random
def count_occurences(arr, x):
    count = 0
    for item in arr:
        if item == x:
            count += 1
    return count

lstIn = li = random.choices(range(1, 101), k=100000)
intIn = random.randint(1, 101)
print(lstIn, intIn)
count_occurences(lstIn, intIn)
# Out:
# [9, 15, 17, 51, 85, 44, 94, 13, 69, 21, 46, 1, 17, 59, 25, 62, 56, 3, 68, 49, 65, 89, 47, 42, 60, 14, 78, 89, 29, 31, 43, 54, 50, 37, 23, 61, 51, 25, 94, 56, 79, 63, 59, 1, 90, 34, 86, 93, 79, 26, 85, 18, 63, 53, 14, 40, 7, 20, 84, 30, 19, 11, 14, 18, 46, 35, 72, 33, 41, 44, 68, 97, 100, 99, 12, 27, 81, 25, 65, 45, 53, 37, 75, 89, 22, 17, 29, 83, 82, 56, 50, 31, 33, 60, 48, 33, 39, 47, 78, 74, 77, 42, 45, 71, 24, 47, 55, 7, 52, 88, 40, 83, 88, 13, 7, 46, 55, 35, 24, 38, 38, 53, 14, 8, 26, 66, 32, 76, 28, 31, 92, 48, 93, 41, 58, 52, 12, 20, 1, 80, 1, 67, 34, 82, 83, 20, 65, 33, 6, 5, 92, 11, 20, 93, 3, 26, 97, 30, 18, 28, 56, 17, 34, 93, 88, 54, 5, 49, 73, 23, 13, 31, 56, 94, 71, 48, 78, 34, 53, 70, 10, 80, 59, 35, 1, 66, 46, 1, 9, 10, 2, 87, 79, 91, 44, 9, 64, 4, 74, 22, 65, 42, 52, 26, 82, 43, 77, 89, 76, 55, 93, 88, 24, 34, 41, 90, 55, 5, 52, 27, 78, 6, 18, 35, 67, 27, 14, 5, 65, 12, 63, 87, 95, 13, 62, 64, 62, 83, 41, 92, 43, 94, 36, 81, 77, 13, 95, 49, 16, 16, 4, 2, 55, 89, 69, 1
# ...

# %%
# W7A3
from timeit import default_timer as timer
# Bubble Sort:
def minimum_index(lst):
    minTemp = lst[0]
    i = 1
    index = 0
    while i < len(lst):
        if lst[i] < minTemp:
            minTemp = lst[i]
            index = i
        i += 1
    return index
def bubble_sort(arr):
    i = 0
    while i < len(arr) - 1:
        if arr[i] > arr[i+1]:
            arr[i], arr[i+1] = arr[i + 1], arr[i]
            i = 0
        else:
            i += 1
    return arr

def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr
# lstIn = list(map(int, input().split()))
lstIn = li = random.choices(range(1, 101), k=100)
selection_sort(lstIn)
# Out:
# 1.0273837999993702

# %%
# W7A4

lstIn = list(map(int, input().split()))
dictTemp = {}
for i in range(len(lstIn)):
    if lstIn[i] not in dictTemp.keys():
        dictTemp[lstIn[i]] = [i]
    else:
        dictTemp[lstIn[i]].append(i)
maxCountTemp = -1
lstTemp = []
for item in dictTemp.keys():
    if len(dictTemp[item]) > maxCountTemp:
        maxCountTemp = len(dictTemp[item])
for item in dictTemp.keys():
    if len(dictTemp[item]) == maxCountTemp:
        print(f"{item} xuat hien nhieu nhat, som nhat, {maxCountTemp} lan.")
        break
# Out:
# 1 xuat hien nhieu nhat, som nhat, 3 lan.

# %%
# W7A5

lstIn = list(map(int, input().split()))
intIn = int(input())

count = 0
for i in range(len(lstIn)):
    for j in range(i+1, len(lstIn)):
        if lstIn[i] + lstIn[j] == intIn:
            count += 1

print(count)
# Out:
# 9

# %%
# W7A6

rowCount = int(input())
matrix = []
for i in range(rowCount):
    tempRow = list(map(int, input().split()))
    matrix.append(tempRow)
flattenArray = []
for i in range(rowCount):
    if i % 2 == 0:
        flattenArray += matrix[i]
    else:
        flattenArray += matrix[i][::-1]
print(flattenArray)
# Out:
# [1, 23, 4, 5, 6, 8, 7]

# %%
# W7A7
# Quy hoạch động

lstIn = list(map(int, input().split()))
lstDP = [0] + lstIn
dpTempList = [1] * len(lstDP)
dpTempList[0] = 0
for i in range(1, len(lstDP)):
    for j in range(i-1, 0, -1):
        if lstDP[i] > lstDP[j]:
            dpTempList[i] = max(dpTempList[i], dpTempList[j] + 1)
print(max(dpTempList))
# Out:
# [0, 1, 2, 1, 3, 3, 4]

# %%
# W7A8
def length_interval(arr): # 2 phần tử
    return arr[1] - arr[0] + 1
def in_interval(num, arr): # 2 phần tử
    return arr[0] < num and num < arr[1]
lstIn1 = eval(input())
lstIn2 = eval(input())
for num in lstIn2:
    lengthMin = length_interval()
    for item in lstIn1:
        if in_interval(num, item):

# %%
# W7A9

lstIn = list(map(int, input().split()))
lstTemp = []
length = len(lstIn)
for i in range(length):
    tempCount = 0
    for j in range(i, length):
        if lstIn[j] < lstIn[i]:
            tempCount += 1
    lstTemp.append(tempCount)
print(lstTemp)
# Out:
# [4, 3, 2, 1, 0]

# %%
# W7A10

def prefix_sum(arr, i):
    return sum(arr[0:(i+1)])

lstIn = list(map(int, input().split()))
n = int(input())
for i in range(len(lstIn)):
    prefix_sum_modulo = prefix_sum(lstIn, i)
    
    lstTemp = []
    if prefix
# Out:
# 10

# %%
# W7A11

strIn = input()
findstrIn = input()
lengthstrIn = len(findstrIn)
i = 0
count = 0
while True:
    i = strIn.find(findstrIn)
    if i == -1:
        break
    else:
        count += 1
        strIn = strIn[:i] + strIn[(i+lengthstrIn):]
print(count)
# Out:
# 1

# %%
# W7A12
def bubble_sort(arr):
    i = 0
    while i < len(arr) - 1:
        if arr[i] > arr[i+1]:
            arr[i], arr[i+1] = arr[i+1], arr[i]
            i = 0
        else:
            i += 1
    return arr
dictIn = {}
for i in range(4):
    temp = input()
    dictIn[temp] = chr(ord("A")+i)
lstTemp = list(dictIn.keys())
strOut = " ".join(dictIn[item] for item in bubble_sort(lstTemp))
print(strOut)
# Out:
# C A D B

# %%
# W7A15

n = int(input())
lstIn = []
for i in range(n):
    lstIn.append(input())
for i in range(len(lstIn)):
    if lstIn[i] == "Nemo":
        if i == len(lstIn) - 1:
            print(f"{lstIn[i-1]} and {lstIn[0]}")
        else:
            print(f"{lstIn[i-1]} and {lstIn[i+1]}")
# Out:
# F and G
